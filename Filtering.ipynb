# %%
import pandas as pd

# %%
data = pd.read_csv('Coaches.csv')

# %%
data.head()
# Out:
#               Name            NOC  Discipline Event
# 0  ABDELMAGID Wael          Egypt    Football   NaN
# 1        ABE Junya          Japan  Volleyball   NaN
# 2    ABE Katsuhiko          Japan  Basketball   NaN
# 3     ADAMA Cherif  Côte d'Ivoire    Football   NaN
# 4       AGEBA Yuya          Japan  Volleyball   NaN

# %%
data[data['Name']>'A']
# Out:
#                        Name                         NOC         Discipline  \
# 0           ABDELMAGID Wael                       Egypt           Football
# 1                 ABE Junya                       Japan         Volleyball
# 2             ABE Katsuhiko                       Japan         Basketball
# 3              ADAMA Cherif               Côte d'Ivoire           Football
# 4                AGEBA Yuya                       Japan         Volleyball
# ..                      ...                         ...                ...
# 389  ZAMORA PEDREIRA Javier                       Spain         Basketball
# 390      ZAMPIERI Francesca               Liechtenstein  Artistic Swimming
# 391          ZHANG Xiaohuan  People's Republic of China  Artistic Swimming
# 392              ZIJP Simon                 Netherlands             Hockey
# 393           ZONDI Nkuliso                South Africa             Hockey
#
#      Event
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 394 entries, 0 to 393
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        394 non-null    object
#  1   NOC         394 non-null    object
#  2   Discipline  394 non-null    object
#  3   Event       249 non-null    object
# dtypes: object(4)
# memory usage: 12.4+ KB

# %%
# Data Filtering w NOC = Japan and Discipline = Volleyball

data[(data['NOC']=='Japan') & (data['Discipline']=='Volleyball')]
# Out:
#                   Name    NOC  Discipline  Event
# 1            ABE Junya  Japan  Volleyball    NaN
# 4           AGEBA Yuya  Japan  Volleyball    NaN
# 269        NAGAE Shoji  Japan  Volleyball    NaN
# 271        NAKADA Kumi  Japan  Volleyball  Women
# 272  NAKAGAICHI Yuichi  Japan  Volleyball    Men

# %%
# str.contains

data[(data['Name'].str.contains('ABE'))]
# Out:
#                   Name    NOC    Discipline Event
# 1            ABE Junya  Japan    Volleyball   NaN
# 2        ABE Katsuhiko  Japan    Basketball   NaN
# 20  BABER Gareth Colin   Fiji  Rugby Sevens   Men

# %%
# isin

data[(data['NOC'].isin(['Japan']))]
# Out:
#                           Name    NOC         Discipline     Event
# 1                    ABE Junya  Japan         Volleyball       NaN
# 2                ABE Katsuhiko  Japan         Basketball       NaN
# 4                   AGEBA Yuya  Japan         Volleyball       NaN
# 5    AIKMAN Siegfried Gottlieb  Japan             Hockey       Men
# 17          ARNAU CREUS Xavier  Japan             Hockey     Women
# 53           CASAREZ Mary Lucy  Japan  Baseball/Softball  Softball
# 91              EITOKU Atsushi  Japan  Artistic Swimming       NaN
# 166            HIROSE Norikazu  Japan           Football       NaN
# 169       HOVASSE Thomas Wayne  Japan         Basketball     Women
# 172               IMURA Masayo  Japan  Artistic Swimming       NaN
# 173           IWABUCHI Kensuke  Japan       Rugby Sevens       Men
# 185              KANEKO Makoto  Japan  Baseball/Softball  Baseball
# 188               KAWASE Asaki  Japan           Football       NaN
# ...

# %%
# startswith

data[(data['Event'].isin(['Men'])) & (data['Name'].str.startswith('OMOTO'))]
# Out:
#            Name    NOC  Discipline Event
# 280  OMOTO Yoji  Japan  Water Polo   Men

# %%
# query

data.query('NOC == "Germany"')
# Out:
#                  Name      NOC  Discipline  Event
# 6       AL SAADI Kais  Germany      Hockey    Men
# 47     BUSENKELL Axel  Germany    Football    NaN
# 130   GISLASON Alfred  Germany    Handball    Men
# 140   GRESKOWIAK Arne  Germany  Basketball    NaN
# 160      HENKEL Claas  Germany      Hockey    Men
# 190    KELLER Florian  Germany      Hockey  Women
# 207      KUNTZ Stefan  Germany    Football    Men
# 302  RECKINGER Xavier  Germany      Hockey  Women
# 313      ROEDL Henrik  Germany  Basketball    Men
