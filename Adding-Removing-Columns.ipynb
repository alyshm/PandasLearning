# %%
import pandas as pd

# %%
data = pd.read_csv('Coaches.csv')

# %%
data.head()
# Out:
#               Name            NOC  Discipline Event
# 0  ABDELMAGID Wael          Egypt    Football   NaN
# 1        ABE Junya          Japan  Volleyball   NaN
# 2    ABE Katsuhiko          Japan  Basketball   NaN
# 3     ADAMA Cherif  Côte d'Ivoire    Football   NaN
# 4       AGEBA Yuya          Japan  Volleyball   NaN

# %%
data['Medals'] = 'Gold'

# %%
data.head()
# Out:
#               Name            NOC  Discipline Event Medals
# 0  ABDELMAGID Wael          Egypt    Football   NaN   Gold
# 1        ABE Junya          Japan  Volleyball   NaN   Gold
# 2    ABE Katsuhiko          Japan  Basketball   NaN   Gold
# 3     ADAMA Cherif  Côte d'Ivoire    Football   NaN   Gold
# 4       AGEBA Yuya          Japan  Volleyball   NaN   Gold

# %%
import numpy as np
data['New_Medals']=np.where(data['NOC']=='Japan','Gold','Silver')

# %%
data.head()
# Out:
#               Name            NOC  Discipline Event Medals New_Medals
# 0  ABDELMAGID Wael          Egypt    Football   NaN   Gold     Silver
# 1        ABE Junya          Japan  Volleyball   NaN   Gold       Gold
# 2    ABE Katsuhiko          Japan  Basketball   NaN   Gold       Gold
# 3     ADAMA Cherif  Côte d'Ivoire    Football   NaN   Gold     Silver
# 4       AGEBA Yuya          Japan  Volleyball   NaN   Gold       Gold

# %%
data.drop(columns=['Medals'])
# Out:
#                        Name                         NOC         Discipline  \
# 0           ABDELMAGID Wael                       Egypt           Football
# 1                 ABE Junya                       Japan         Volleyball
# 2             ABE Katsuhiko                       Japan         Basketball
# 3              ADAMA Cherif               Côte d'Ivoire           Football
# 4                AGEBA Yuya                       Japan         Volleyball
# ..                      ...                         ...                ...
# 389  ZAMORA PEDREIRA Javier                       Spain         Basketball
# 390      ZAMPIERI Francesca               Liechtenstein  Artistic Swimming
# 391          ZHANG Xiaohuan  People's Republic of China  Artistic Swimming
# 392              ZIJP Simon                 Netherlands             Hockey
# 393           ZONDI Nkuliso                South Africa             Hockey
#
#      Event New_Medals
# 0      NaN     Silver
# ...

# %%
data.drop([0])
# Out:
#                           Name                         NOC         Discipline  \
# 1                    ABE Junya                       Japan         Volleyball
# 2                ABE Katsuhiko                       Japan         Basketball
# 3                 ADAMA Cherif               Côte d'Ivoire           Football
# 4                   AGEBA Yuya                       Japan         Volleyball
# 5    AIKMAN Siegfried Gottlieb                       Japan             Hockey
# ..                         ...                         ...                ...
# 389     ZAMORA PEDREIRA Javier                       Spain         Basketball
# 390         ZAMPIERI Francesca               Liechtenstein  Artistic Swimming
# 391             ZHANG Xiaohuan  People's Republic of China  Artistic Swimming
# 392                 ZIJP Simon                 Netherlands             Hockey
# 393              ZONDI Nkuliso                South Africa             Hockey
#
#      Event Medals New_Medals
# ...

# %%
data
# Out:
#                        Name                         NOC         Discipline  \
# 0           ABDELMAGID Wael                       Egypt           Football
# 1                 ABE Junya                       Japan         Volleyball
# 2             ABE Katsuhiko                       Japan         Basketball
# 3              ADAMA Cherif               Côte d'Ivoire           Football
# 4                AGEBA Yuya                       Japan         Volleyball
# ..                      ...                         ...                ...
# 389  ZAMORA PEDREIRA Javier                       Spain         Basketball
# 390      ZAMPIERI Francesca               Liechtenstein  Artistic Swimming
# 391          ZHANG Xiaohuan  People's Republic of China  Artistic Swimming
# 392              ZIJP Simon                 Netherlands             Hockey
# 393           ZONDI Nkuliso                South Africa             Hockey
#
#      Event Medals New_Medals
# 0      NaN   Gold     Silver
# ...

# %%
# Now, its permanently delete
# inplace

data.drop(columns=['Medals'],inplace=True)

# %%
data
# Out:
#                        Name                         NOC         Discipline  \
# 0           ABDELMAGID Wael                       Egypt           Football
# 1                 ABE Junya                       Japan         Volleyball
# 2             ABE Katsuhiko                       Japan         Basketball
# 3              ADAMA Cherif               Côte d'Ivoire           Football
# 4                AGEBA Yuya                       Japan         Volleyball
# ..                      ...                         ...                ...
# 389  ZAMORA PEDREIRA Javier                       Spain         Basketball
# 390      ZAMPIERI Francesca               Liechtenstein  Artistic Swimming
# 391          ZHANG Xiaohuan  People's Republic of China  Artistic Swimming
# 392              ZIJP Simon                 Netherlands             Hockey
# 393           ZONDI Nkuliso                South Africa             Hockey
#
#      Event New_Medals
# 0      NaN     Silver
# ...

# %% [markdown]
# **CONVERTING DATATYPE**

# %%
# Converting date into datetime (You can also choose format for dates)
data['born_datetime'] = pd.to_datetime(data['born_date'], format = "%Y-%M-%D")

# Converting year into date-year
data['born_year'] = data['born_year']dt.year

# %% [markdown]
# **SAVING .csv**

# %%
data_new.to_csv('path address', index = False)
